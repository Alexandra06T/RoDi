# %% [markdown]
# # Romanian-Transformers Model Evaluation
#
# Use this colab to evaluate _tranformer model performance_. We currently support:
#
# *   [**Named Entity Recognition**](https://github.com/dumitrescustefan/ronec), based on RONECv2
# *   [**Part of Speech Tagging**](https://github.com/dumitrescustefan/ro-pos-tagger), based on UD's Ro-RRT dataset
# *   [**Semantic Textual Simiarity**](https://github.com/dumitrescustefan/RO-STS), based on RO-STS
# *   [**Emotion Detection in Tweets**](https://github.com/Alegzandra/RED-Romanian-Emotions-Dataset), based on REDv2
# *   [**Perplexity**](https://github.com/dumitrescustefan/wiki-ro), based on wiki-ro, only for generative models
#
# **How to use:**
# 1. Choose the model in the dropdown below.
# 2. Choose the task
# 3. Choose the number of iterations (how many times to run the same task and average over)
# 4. Run all cells ($\color{red}{\text{Ctrl+F9}}$); you will see the averaged results printed at the bottom, as well as saved as jsons in each task's respective folder.
#
# ** Note: Use a GPU runtime and a browser addon (like Colab Auto Reconnect) to keep this session open - some tasks, with 5 iterations, might take some hours to complete.
# This is the official script used to measure model performance on
# the [Romanian-Transformers repo](https://github.com/dumitrescustefan/Romanian-Transformers).
#
#
# ---

# %%
#@title Evaluation parameters

model = 'bert-base-multilingual-cased' #@param ["dumitrescustefan/gpt-neo-romanian-780m", "dumitrescustefan/bert-base-romanian-cased-v1","dumitrescustefan/bert-base-romanian-uncased-v1", "racai/distilbert-base-romanian-cased", "readerbench/RoGPT2-base", "readerbench/RoGPT2-medium", "readerbench/RoGPT2-large", "xlm-roberta-base", "bert-base-multilingual-cased", "bert-base-multilingual-uncased", "readerbench/RoBERT-small", "readerbench/RoBERT-base", "readerbench/RoBERT-large"] {allow-input: true}
task = 'Named Entity Recognition' #@param ["Named Entity Recognition", "POS Tagging", "Emotion Detection in Tweets", "Semantic Textual Similarity", "CLM Perplexity"]
iterations = '1' #@param ["1", "2", "3", "5"]

print("\nWe are going to eval \033[92m{}\033[0m on the \033[92m{}\033[0m task for \033[92m{}\033[0m iteration(s).\n".format(model, task, iterations))

import torch
if not torch.cuda.is_available():
  print(f"\033[101m*** Please use a GPU-enabled colab! ***\033[0m")
else:
  print(f"\nRunning on a \033[92m{torch.cuda.get_device_name(0)}\033[0m with \033[92m{torch.cuda.get_device_properties(0).total_memory/1024/1024/1024:.0f}GB\033[0m RAM.")
# Out:
# We are going to eval bert-base-multilingual-cased on the Named Entity Recognition task for 1 iteration(s).
#
#
# Running on a Tesla T4 with 15GB RAM.

# %% [markdown]
# ##### Code section, run every cell automatically with Ctrl+F9

# %%
# "robert" | "mbert"
MODEL_KEY  = "mbert"
# "diac" | "nodiac"
TRAIN_COND = "diac"

RUN_NAME = f"{MODEL_KEY}_train_{TRAIN_COND}"

MODEL_HUB = {
    "robert": "dumitrescustefan/bert-base-romanian-cased-v1",
    "mbert":  "bert-base-multilingual-cased",
}[MODEL_KEY]

# SEED = 315 # first iteration
SEED = 222 # second iteration
# SEED = 156 # third iteration

# %%
import os

BASE     = f"/kaggle/working/{RUN_NAME}"
CKPT_DIR = f"{BASE}/checkpoints"
RES_DIR  = f"{BASE}/results"
PRED_DIR = f"{BASE}/predictions"

for d in [BASE, CKPT_DIR, RES_DIR, PRED_DIR]:
    os.makedirs(d, exist_ok=True)

# %%
diac_train_file='/kaggle/input/datasets/tomaalexandra06/ronec-diac/train.json'
diac_validation_file='/kaggle/input/datasets/tomaalexandra06/ronec-diac/valid.json'
diac_test_file='/kaggle/input/datasets/tomaalexandra06/ronec-diac/test.json'

# %%
def eval_ner(model, iterations, batch_size, accumulate_grad_batches):
  print("\033[92mPreparing environment ...\033[0m")
  # !git clone https://github.com/Alexandra06T/RoDi-Utils.git
  # !pip3 install -r RoDi-Utils/requirements.txt -q


  print("\033[92mRunning task ...\033[0m")
  # !cd RoDi-Utils && python evaluate.py --batch_size={batch_size} --accumulate_grad_batches={accumulate_grad_batches} --model_name={model} --train_file={diac_train_file} --validation_file={diac_validation_file} --test_file={diac_test_file} --dirpath={CKPT_DIR} --seed={SEED} --strategy=auto --devices=2
  # !python evaluate.py --batch_size=$batch_size --accumulate_grad_batches=$accumulate_grad_batches --model_name $model --train_file $nodiac_train_file --validation_file $nodiac_validation_file --test_file $nodiac_test_file --dirpath $CKPT_DIR --seed $SEED

  return None

# configs
batch_size, accumulate_grad_batches = 8, 1
if "-large" in model or "-medium" in model:
  batch_size = 1
  accumulate_grad_batches = 8

# %%
# run
if task == "Named Entity Recognition":
  eval_ner(model, iterations, batch_size, accumulate_grad_batches)
# Out:
# Preparing environment ...
# Cloning into 'RoDi-Utils'...
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 13 (delta 4), reused 12 (delta 3), pack-reused 0 (from 0)
# Receiving objects: 100% (13/13), 6.05 KiB | 3.03 MiB/s, done.
# Resolving deltas: 100% (4/4), done.
# Running task ...
# Seed set to 222
# Loading data...
# 	Dataset contains 31 BIO2 classes: ['O', 'B-PERSON', 'I-PERSON', 'B-ORG', 'I-ORG', 'B-GPE', 'I-GPE', 'B-LOC', 'I-LOC', 'B-NAT_REL_POL', 'I-NAT_REL_POL', 'B-EVENT', 'I-EVENT', 'B-LANGUAGE', 'I-LANGUAGE', 'B-WORK_OF_ART', 'I-WORK_OF_ART', 'B-DATETIME', 'I-DATETIME', 'B-PERIOD', 'I-PERIOD', 'B-MONEY', 'I-MONEY', 'B-QUANTITY', 'I-QUANTITY', 'B-NUMERIC', 'I-NUMERIC', 'B-ORDINAL', 'I-ORDINAL', 'B-FACILITY', 'I-FACILITY'].
# 	There are 16 classes: ['O', 'PERSON', 'ORG', 'GPE', 'LOC', 'NAT_REL_POL', 'EVENT', 'LANGUAGE', 'WORK_OF_ART', 'DATETIME', 'PERIOD', 'MONEY', 'QUANTITY', 'NUMERIC', 'ORDINAL', 'FACILITY']
#
# 2026-07-25 17:56:41 httpx INFO: HTTP Request: HEAD https://huggingface.co/bert-base-multilingual-cased/resolve/main/config.json "HTTP/1.1 200 OK"
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-07-25 17:56:41 huggingface_hub.utils._http WARNING: Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-07-25 17:56:41 httpx INFO: HTTP Request: GET https://huggingface.co/bert-base-multilingual-cased/resolve/main/config.json "HTTP/1.1 200 OK"
# config.json: 100%|█████████████████████████████| 625/625 [00:00<00:00, 2.39MB/s]
# 2026-07-25 17:56:41 httpx INFO: HTTP Request: HEAD https://huggingface.co/bert-base-multilingual-cased/resolve/main/tokenizer_config.json "HTTP/1.1 200 OK"
# 2026-07-25 17:56:41 httpx INFO: HTTP Request: GET https://huggingface.co/bert-base-multilingual-cased/resolve/main/tokenizer_config.json "HTTP/1.1 200 OK"
# tokenizer_config.json: 100%|██████████████████| 49.0/49.0 [00:00<00:00, 246kB/s]
# 2026-07-25 17:56:41 httpx INFO: HTTP Request: GET https://huggingface.co/api/models/bert-base-multilingual-cased/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 307 Temporary Redirect"
# 2026-07-25 17:56:41 httpx INFO: HTTP Request: GET https://huggingface.co/api/models/google-bert/bert-base-multilingual-cased/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# 2026-07-25 17:56:41 httpx INFO: HTTP Request: GET https://huggingface.co/api/models/bert-base-multilingual-cased/tree/main?recursive=true&expand=false "HTTP/1.1 307 Temporary Redirect"
# 2026-07-25 17:56:41 httpx INFO: HTTP Request: GET https://huggingface.co/api/models/google-bert/bert-base-multilingual-cased/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# 2026-07-25 17:56:41 httpx INFO: HTTP Request: HEAD https://huggingface.co/bert-base-multilingual-cased/resolve/main/vocab.txt "HTTP/1.1 200 OK"
# 2026-07-25 17:56:41 httpx INFO: HTTP Request: GET https://huggingface.co/bert-base-multilingual-cased/resolve/main/vocab.txt "HTTP/1.1 200 OK"
# vocab.txt: 996kB [00:00, 19.5MB/s]
# 2026-07-25 17:56:41 httpx INFO: HTTP Request: HEAD https://huggingface.co/bert-base-multilingual-cased/resolve/main/tokenizer.json "HTTP/1.1 200 OK"
# 2026-07-25 17:56:41 httpx INFO: HTTP Request: GET https://huggingface.co/bert-base-multilingual-cased/resolve/main/tokenizer.json "HTTP/1.1 200 OK"
# tokenizer.json: 1.96MB [00:00, 15.2MB/s]
# 2026-07-25 17:56:42 httpx INFO: HTTP Request: HEAD https://huggingface.co/bert-base-multilingual-cased/resolve/main/added_tokens.json "HTTP/1.1 404 Not Found"
# 2026-07-25 17:56:42 httpx INFO: HTTP Request: HEAD https://huggingface.co/bert-base-multilingual-cased/resolve/main/special_tokens_map.json "HTTP/1.1 404 Not Found"
# 2026-07-25 17:56:42 httpx INFO: HTTP Request: HEAD https://huggingface.co/bert-base-multilingual-cased/resolve/main/chat_template.jinja "HTTP/1.1 404 Not Found"
# 2026-07-25 17:56:42 httpx INFO: HTTP Request: GET https://huggingface.co/api/models/bert-base-multilingual-cased "HTTP/1.1 307 Temporary Redirect"
# 2026-07-25 17:56:42 httpx INFO: HTTP Request: GET https://huggingface.co/api/models/google-bert/bert-base-multilingual-cased "HTTP/1.1 200 OK"
# 	Train dataset has 9000 instances.
# 	Valid dataset has 1330 instances.
# 	Test dataset has 2000 instances.
#
# Running experiment 1/1
# Loading AutoModel [bert-base-multilingual-cased] ...
# 2026-07-25 17:56:42 httpx INFO: HTTP Request: HEAD https://huggingface.co/bert-base-multilingual-cased/resolve/main/config.json "HTTP/1.1 200 OK"
# 2026-07-25 17:56:42 httpx INFO: HTTP Request: HEAD https://huggingface.co/bert-base-multilingual-cased/resolve/main/adapter_config.json "HTTP/1.1 404 Not Found"
# 2026-07-25 17:56:43 httpx INFO: HTTP Request: HEAD https://huggingface.co/bert-base-multilingual-cased/resolve/main/config.json "HTTP/1.1 200 OK"
# 2026-07-25 17:56:43 httpx INFO: HTTP Request: HEAD https://huggingface.co/bert-base-multilingual-cased/resolve/main/model.safetensors "HTTP/1.1 302 Found"
# 2026-07-25 17:56:43 httpx INFO: HTTP Request: GET https://huggingface.co/api/models/google-bert/bert-base-multilingual-cased/xet-read-token/3f076fdb1ab68d5b2880cb87a0886f315b8146f8 "HTTP/1.1 200 OK"
# model.safetensors: 100%|██████████████████████| 714M/714M [00:04<00:00, 168MB/s]
# Loading weights: 100%|█| 197/197 [00:00<00:00, 1441.73it/s, Materializing param=
# BertForTokenClassification LOAD REPORT from: bert-base-multilingual-cased
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |
# cls.seq_relationship.bias                  | UNEXPECTED |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |
# cls.predictions.transform.dense.weight     | UNEXPECTED |
# bert.pooler.dense.bias                     | UNEXPECTED |
# bert.pooler.dense.weight                   | UNEXPECTED |
# cls.seq_relationship.weight                | UNEXPECTED |
# cls.predictions.transform.dense.bias       | UNEXPECTED |
# cls.predictions.bias                       | UNEXPECTED |
# classifier.weight                          | MISSING    |
# classifier.bias                            | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/2
# [rank: 1] Seed set to 222
# Loading data...
# 	Dataset contains 31 BIO2 classes: ['O', 'B-PERSON', 'I-PERSON', 'B-ORG', 'I-ORG', 'B-GPE', 'I-GPE', 'B-LOC', 'I-LOC', 'B-NAT_REL_POL', 'I-NAT_REL_POL', 'B-EVENT', 'I-EVENT', 'B-LANGUAGE', 'I-LANGUAGE', 'B-WORK_OF_ART', 'I-WORK_OF_ART', 'B-DATETIME', 'I-DATETIME', 'B-PERIOD', 'I-PERIOD', 'B-MONEY', 'I-MONEY', 'B-QUANTITY', 'I-QUANTITY', 'B-NUMERIC', 'I-NUMERIC', 'B-ORDINAL', 'I-ORDINAL', 'B-FACILITY', 'I-FACILITY'].
# 	There are 16 classes: ['O', 'PERSON', 'ORG', 'GPE', 'LOC', 'NAT_REL_POL', 'EVENT', 'LANGUAGE', 'WORK_OF_ART', 'DATETIME', 'PERIOD', 'MONEY', 'QUANTITY', 'NUMERIC', 'ORDINAL', 'FACILITY']
#
# 2026-07-25 17:56:58 httpx INFO: HTTP Request: HEAD https://huggingface.co/bert-base-multilingual-cased/resolve/main/config.json "HTTP/1.1 200 OK"
# 2026-07-25 17:56:58 httpx INFO: HTTP Request: HEAD https://huggingface.co/bert-base-multilingual-cased/resolve/main/tokenizer_config.json "HTTP/1.1 200 OK"
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-07-25 17:56:58 huggingface_hub.utils._http WARNING: Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-07-25 17:56:59 httpx INFO: HTTP Request: GET https://huggingface.co/api/models/bert-base-multilingual-cased/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 307 Temporary Redirect"
# 2026-07-25 17:56:59 httpx INFO: HTTP Request: GET https://huggingface.co/api/models/google-bert/bert-base-multilingual-cased/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# 2026-07-25 17:56:59 httpx INFO: HTTP Request: GET https://huggingface.co/api/models/bert-base-multilingual-cased/tree/main?recursive=true&expand=false "HTTP/1.1 307 Temporary Redirect"
# 2026-07-25 17:56:59 httpx INFO: HTTP Request: GET https://huggingface.co/api/models/google-bert/bert-base-multilingual-cased/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# 2026-07-25 17:56:59 httpx INFO: HTTP Request: GET https://huggingface.co/api/models/bert-base-multilingual-cased "HTTP/1.1 307 Temporary Redirect"
# 2026-07-25 17:57:00 httpx INFO: HTTP Request: GET https://huggingface.co/api/models/google-bert/bert-base-multilingual-cased "HTTP/1.1 200 OK"
# 	Train dataset has 9000 instances.
# 	Valid dataset has 1330 instances.
# 	Test dataset has 2000 instances.
#
# Running experiment 1/1
# Loading AutoModel [bert-base-multilingual-cased] ...
# 2026-07-25 17:57:00 httpx INFO: HTTP Request: HEAD https://huggingface.co/bert-base-multilingual-cased/resolve/main/config.json "HTTP/1.1 200 OK"
# 2026-07-25 17:57:00 httpx INFO: HTTP Request: HEAD https://huggingface.co/bert-base-multilingual-cased/resolve/main/config.json "HTTP/1.1 200 OK"
# Loading weights: 100%|█| 197/197 [00:00<00:00, 1478.83it/s, Materializing param=
# BertForTokenClassification LOAD REPORT from: bert-base-multilingual-cased
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.predictions.bias                       | UNEXPECTED |
# cls.predictions.transform.dense.bias       | UNEXPECTED |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |
# cls.predictions.transform.dense.weight     | UNEXPECTED |
# bert.pooler.dense.weight                   | UNEXPECTED |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |
# cls.seq_relationship.weight                | UNEXPECTED |
# bert.pooler.dense.bias                     | UNEXPECTED |
# cls.seq_relationship.bias                  | UNEXPECTED |
# classifier.weight                          | MISSING    |
# classifier.bias                            | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Initializing distributed: GLOBAL_RANK: 1, MEMBER: 2/2
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 2 processes
# ----------------------------------------------------------------------------------------------------
#
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1]
# ┏━━━┳━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━┳━━━━━━━┓
# ┃   ┃ Name  ┃ Type                       ┃ Params ┃ Mode ┃ FLOPs ┃
# ┡━━━╇━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━╇━━━━━━━┩
# │ 0 │ model │ BertForTokenClassification │  177 M │ eval │     0 │
# └───┴───────┴────────────────────────────┴────────┴──────┴───────┘
# Trainable params: 177 M
# Non-trainable params: 0
# Total params: 177 M
# Total estimated model params size (MB): 709.147
# Modules in train mode: 0
# Modules in eval mode: 228
# Total FLOPs: 0
# /usr/local/lib/python3.12/dist-packages/pytorch_lightning/utilities/_pytree.py:21: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
# /usr/local/lib/python3.12/dist-packages/pytorch_lightning/utilities/_pytree.py:2
# 1: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec,
# TreeSpec) and treespec.is_leaf()` instead.
# /usr/local/lib/python3.12/dist-packages/pytorch_lightning/trainer/connectors/log0 14.45it/s 0.00it/s
# ger_connector/result.py:433: It is recommended to use
# `self.log('valid/avg_loss', ..., sync_dist=True)` when logging on epoch level in
# distributed setting to accumulate the metric across devices.
# /usr/local/lib/python3.12/dist-packages/pytorch_lightning/trainer/connectors/logm 14.45it/s
# ger_connector/result.py:433: It is recommended to use
# `self.log('valid/ent_type', ..., sync_dist=True)` when logging on epoch level in
# distributed setting to accumulate the metric across devices.
# /usr/local/lib/python3.12/dist-packages/pytorch_lightning/trainer/connectors/logm 14.45it/s
# ger_connector/result.py:433: It is recommended to use `self.log('valid/partial',
# ..., sync_dist=True)` when logging on epoch level in distributed setting to
# accumulate the metric across devices.
# /usr/local/lib/python3.12/dist-packages/pytorch_lightning/trainer/connectors/logm 14.45it/s
# ger_connector/result.py:433: It is recommended to use `self.log('valid/strict',
# ..., sync_dist=True)` when logging on epoch level in distributed setting to
# accumulate the metric across devices.
# /usr/local/lib/python3.12/dist-packages/pytorch_lightning/trainer/connectors/logm 14.45it/s
# ger_connector/result.py:433: It is recommended to use `self.log('valid/exact',
# ..., sync_dist=True)` when logging on epoch level in distributed setting to
# accumulate the metric across devices.
# /usr/local/lib/python3.12/dist-packages/pytorch_lightning/loops/fit_loop.py:538:m 14.45it/s
# Found 228 module(s) in eval mode at the start of training. This may lead to
# unexpected behavior during training. If this is intentional, you can ignore this
# warning.
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━━━━ 0/563 0:00:00 • -:--:-- 0.00it/s v_num: 0.000/usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py:865: UserWarning: The AccumulateGrad node's stream does not match the stream of the node that produced the incoming gradient. This may incur unnecessary synchronization and break CUDA graph capture if the AccumulateGrad node's stream is the default stream. This mismatch is caused by an AccumulateGrad node created prior to the current iteration being kept alive. This can happen if the autograd graph is still being kept alive by tensors such as the loss, or if you are using DDP, which will stash a reference to the node. To resolve the mismatch, delete all references to the autograd graph or ensure that DDP initialization is performed under the same stream as subsequent forwards. If the mismatch is intentional, you can use torch.autograd.graph.set_warn_on_accumulate_grad_stream_mismatch(False) to suppress this warning. (Triggered internally at /pytorch/torch/csrc/autograd/input_buffer.cpp:240.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py:865:
# UserWarning: The AccumulateGrad node's stream does not match the stream of the
# node that produced the incoming gradient. This may incur unnecessary
# synchronization and break CUDA graph capture if the AccumulateGrad node's stream
# is the default stream. This mismatch is caused by an AccumulateGrad node created
# prior to the current iteration being kept alive. This can happen if the autograd
# graph is still being kept alive by tensors such as the loss, or if you are using
# DDP, which will stash a reference to the node. To resolve the mismatch, delete
# all references to the autograd graph or ensure that DDP initialization is
# performed under the same stream as subsequent forwards. If the mismatch is
# intentional, you can use
# torch.autograd.graph.set_warn_on_accumulate_grad_stream_mismatch(False) to
# suppress this warning. (Triggered internally at
# /pytorch/torch/csrc/autograd/input_buffer.cpp:240.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine
# to run the backward pass
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s v_num: 0.0000.0000.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s  v_num: 0.000
# Epoch 0/999 ━━━━━━━━━━━━━━━━━━━━ 563/563 0:04:14 • 0:00:00 2.21it/s v_num: 0.000.000[rank: 1] Metric valid/strict improved. New best score: 0.853
# [rank: 0] Metric valid/strict improved. New best score: 0.871
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s v_num: 0.0000.0000.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s  v_num: 0.000
# Epoch 1/999 ━━━━━━━━━━━━━━━━━━━━ 563/563 0:04:20 • 0:00:00 2.11it/s v_num: 0.000.000[rank: 1] Metric valid/strict improved by 0.015 >= min_delta = 0.0001. New best score: 0.868
# [rank: 0] Metric valid/strict improved by 0.009 >= min_delta = 0.0001. New best score: 0.881
